# %%
# !pip install kats
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 6.3 MB 921 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 934 kB 19.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 47 kB 6.7 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 64 kB 4.1 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 310 kB 2.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 165 kB 2.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 3.4 MB 1.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 62.6 MB 211 kB/s eta 0:00:01     |████████████████████▏           | 39.5 MB 3.2 MB/s eta 0:00:08
# ...
#      |████████████████████████████████| 247 kB 1.8 MB/s eta 0:00:01
# ...

# %%
import numpy as np
import pandas as pd
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import sys
sys.path.append("../")

import warnings
warnings.filterwarnings('ignore')

from kats.consts import TimeSeriesData

# %%
url = '../data/database-australia/modis_2020_Australia_prepared.csv'
aus_fires = pd.read_csv(url, parse_dates=['acq_date'])
aus_fires.shape
aus_fires.head()
# Out:
#    latitude  longitude   acq_date  fire_count  confidence   frp  \
# 0     -43.5      146.8 2020-03-27           1           0  33.6
# 1     -43.5      146.9 2020-03-18           1         100   0.0
# 2     -43.4      146.9 2020-03-27           2          32  95.8
# 3     -43.4      146.9 2020-03-28           4          75  91.0
# 4     -43.2      147.9 2020-04-09           1           0  12.4
#
#    est_fire_area  est_brightness
# 0            1.2           306.1
# 1            1.7           327.8
# 2            1.3           320.6
# 3            4.2           309.4
# 4            1.2           300.0

# %%
aus_fires = TimeSeriesData(aus_fires)
# Out:
# ERROR:root:Time column time not in DataFrame
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_112132/2865237110.py in <module>
# ----> 1 aus_fires = TimeSeriesData(aus_fires)
#
# ~/.local/lib/python3.8/site-packages/kats/consts.py in __init__(self, df, sort_by_time, time, value, time_col_name, date_format, use_unix_time, unix_time_units, tz, tz_ambiguous, tz_nonexistent)
#     206                 if self.time_col_name not in df.columns:
#     207                     msg = f"Time column {self.time_col_name} not in DataFrame"
# --> 208                     raise _log_error(msg)
#     209                 # Parsing time column into correct format
#     210                 df = df.copy()
#
# ValueError: Time column time not in DataFrame
