# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from IPython.core.interactiveshell import InteractiveShell
import random
InteractiveShell.ast_node_interactivity = "all"
import os
from datetime import datetime
import matplotlib.pyplot as plt
#import plotly.express as px
import glob
from tqdm import tqdm
from sklearn import preprocessing

# %%
# import data
url = '../data/australia_old.csv'
fileName = '../data/australia_old'
aus_fires = pd.read_csv(url, parse_dates=['acq_date'])
aus_fires.shape
aus_fires.head()
# Out:
# (1445364, 15)
#    latitude  longitude  brightness  scan  track   acq_date  acq_time  \
# 0  -14.9764   145.2801       320.6   2.0    1.4 2015-01-01       104
# 1  -15.8931   136.6094       324.4   1.2    1.1 2015-01-01       104
# 2  -18.5115   139.5995       331.8   1.0    1.0 2015-01-01       105
# 3  -19.0015   121.9994       326.9   2.9    1.6 2015-01-01       243
# 4  -18.0765   122.6900       314.5   3.2    1.7 2015-01-01       243
#
#   satellite instrument  confidence  version  bright_t31   frp daynight  type
# 0     Terra      MODIS          24      6.2       294.8  25.0        D     0
# 1     Terra      MODIS          28      6.2       302.3  11.6        D     0
# 2     Terra      MODIS          37      6.2       305.0  19.1        D     0
# 3     Terra      MODIS          37      6.2       300.0  46.9        D     0
# 4     Terra      MODIS          25      6.2       292.5  42.0        D     0

# %%
aus_fires.rename({'acq_date': 'time'}, axis=1, inplace=True)
aus_fires['est_fire_area'] = aus_fires['scan'] * aus_fires['track']
aus_fires['est_brightness'] = (aus_fires['brightness'] + aus_fires['bright_t31'])/2
aus_fires.latitude = aus_fires.latitude.round(1)
aus_fires.longitude = aus_fires.longitude.round(1)
aus_fires = aus_fires[aus_fires.type==0]

aus_fires.shape
aus_fires.head()
# Out:
# (1436163, 17)
#    latitude  longitude  brightness  scan  track       time  acq_time  \
# 0     -15.0      145.3       320.6   2.0    1.4 2015-01-01       104
# 1     -15.9      136.6       324.4   1.2    1.1 2015-01-01       104
# 2     -18.5      139.6       331.8   1.0    1.0 2015-01-01       105
# 3     -19.0      122.0       326.9   2.9    1.6 2015-01-01       243
# 4     -18.1      122.7       314.5   3.2    1.7 2015-01-01       243
#
#   satellite instrument  confidence  version  bright_t31   frp daynight  type  \
# 0     Terra      MODIS          24      6.2       294.8  25.0        D     0
# 1     Terra      MODIS          28      6.2       302.3  11.6        D     0
# 2     Terra      MODIS          37      6.2       305.0  19.1        D     0
# 3     Terra      MODIS          37      6.2       300.0  46.9        D     0
# 4     Terra      MODIS          25      6.2       292.5  42.0        D     0
#
#    est_fire_area  est_brightness
# 0           2.80          307.70
# 1           1.32          313.35
# 2           1.00          318.40
# 3           4.64          313.45
# 4           5.44          303.50

# %%
fires = aus_fires[['latitude', 'longitude', 'time','confidence',
                           'est_fire_area','est_brightness','frp']].copy()
## Add fire_count column
count = fires.groupby(['latitude', 'longitude', 'time']).size().reset_index().rename(columns={0:'fire_count'})
fire_copy = fires.merge(count,how='outer', on=['latitude', 'longitude', 'time'])

fire_copy
# Out:
#          latitude  longitude       time  confidence  est_fire_area  \
# 0           -15.0      145.3 2015-01-01          24           2.80
# 1           -15.9      136.6 2015-01-01          28           1.32
# 2           -18.5      139.6 2015-01-01          37           1.00
# 3           -19.0      122.0 2015-01-01          37           4.64
# 4           -18.1      122.7 2015-01-01          25           5.44
# ...           ...        ...        ...         ...            ...
# 1436158     -26.7      150.7 2020-12-31          35           1.32
# 1436159     -28.3      122.2 2020-12-31          29           3.45
# 1436160     -28.3      122.3 2020-12-31          31           3.30
# 1436161     -28.3      122.3 2020-12-31          65           1.32
# 1436162     -28.3      122.3 2020-12-31         100           1.32
#
#          est_brightness   frp  fire_count
# 0                307.70  25.0           1
# 1                313.35  11.6           1
# 2                318.40  19.1           1
# 3                313.45  46.9           1
# 4                303.50  42.0           2
# ...                 ...   ...         ...
# 1436158          295.85   4.7           1
# 1436159          303.00  38.1           1
# 1436160          299.50  32.8           3
# 1436161          306.00  20.6           3
# 1436162          321.10  69.0           3
#
# [1436163 rows x 8 columns]

# %%
fire_copy = fire_copy.groupby(['latitude', 'longitude', 'time'])[['fire_count','confidence','frp','est_fire_area','est_brightness']].mean().reset_index()
fire_copy
# Out:
#         latitude  longitude       time  fire_count  confidence         frp  \
# 0          -43.5      146.2 2018-03-23         6.0   56.000000   92.700000
# 1          -43.5      146.8 2020-03-27         1.0    0.000000   33.600000
# 2          -43.5      146.9 2020-03-18         1.0  100.000000    0.000000
# 3          -43.4      146.9 2015-04-14         2.0   84.000000   14.750000
# 4          -43.4      146.9 2016-04-24         3.0   64.333333  135.966667
# ...          ...        ...        ...         ...         ...         ...
# 423591      -9.4      142.7 2020-11-12         1.0    0.000000   19.500000
# 423592      -9.3      142.3 2020-11-10         1.0    0.000000    8.500000
# 423593      -9.2      142.2 2018-10-13         1.0   38.000000    8.800000
# 423594      -9.2      142.2 2018-11-23         1.0   37.000000    9.800000
# 423595      -9.2      142.2 2018-11-27         1.0   14.000000   11.000000
#
#         est_fire_area  est_brightness
# 0            5.433333      306.166667
# 1            1.210000      306.100000
# 2            1.680000      327.850000
# 3            1.000000      297.025000
# 4            3.196667      309.383333
# ...               ...             ...
# 423591       2.340000      306.550000
# 423592       1.100000      308.400000
# 423593       1.000000      312.350000
# 423594       1.100000      310.300000
# 423595       1.100000      313.700000
#
# [423596 rows x 8 columns]

# %%
## Add location count
count = fire_copy.groupby(['latitude', 'longitude']).size().reset_index().rename(columns={0:'loc_count'})
fire_copy = fire_copy.merge(count,how='outer', on=['latitude', 'longitude'])

fire_copy
# Out:
#         latitude  longitude       time  fire_count  confidence         frp  \
# 0          -43.5      146.2 2018-03-23         6.0   56.000000   92.700000
# 1          -43.5      146.8 2020-03-27         1.0    0.000000   33.600000
# 2          -43.5      146.9 2020-03-18         1.0  100.000000    0.000000
# 3          -43.4      146.9 2015-04-14         2.0   84.000000   14.750000
# 4          -43.4      146.9 2016-04-24         3.0   64.333333  135.966667
# ...          ...        ...        ...         ...         ...         ...
# 423591      -9.4      142.7 2020-11-12         1.0    0.000000   19.500000
# 423592      -9.3      142.3 2020-11-10         1.0    0.000000    8.500000
# 423593      -9.2      142.2 2018-10-13         1.0   38.000000    8.800000
# 423594      -9.2      142.2 2018-11-23         1.0   37.000000    9.800000
# 423595      -9.2      142.2 2018-11-27         1.0   14.000000   11.000000
#
#         est_fire_area  est_brightness  loc_count
# 0            5.433333      306.166667          1
# 1            1.210000      306.100000          1
# 2            1.680000      327.850000          1
# 3            1.000000      297.025000         12
# 4            3.196667      309.383333         12
# ...               ...             ...        ...
# 423591       2.340000      306.550000          5
# 423592       1.100000      308.400000          1
# 423593       1.000000      312.350000          3
# 423594       1.100000      310.300000          3
# 423595       1.100000      313.700000          3
#
# [423596 rows x 9 columns]

# %%
fire_copy.est_fire_area = fire_copy.est_fire_area.round(1)
fire_copy.est_brightness = fire_copy.est_brightness.round(1)
fire_copy.confidence = fire_copy.confidence.round().astype(int)
fire_copy.frp = fire_copy.frp.round(1)
fire_copy.fire_count = fire_copy.fire_count.round().astype(int)

fire_copy.head(20)
# Out:
#     latitude  longitude       time  fire_count  confidence    frp  \
# 0      -43.5      146.2 2018-03-23           6          56   92.7
# 1      -43.5      146.8 2020-03-27           1           0   33.6
# 2      -43.5      146.9 2020-03-18           1         100    0.0
# 3      -43.4      146.9 2015-04-14           2          84   14.8
# 4      -43.4      146.9 2016-04-24           3          64  136.0
# 5      -43.4      146.9 2016-04-25           2          66   45.7
# 6      -43.4      146.9 2017-05-19           1          88   74.0
# 7      -43.4      146.9 2018-04-04           3          79  148.4
# 8      -43.4      146.9 2018-04-20           1          28   15.3
# 9      -43.4      146.9 2018-05-01           2          69  100.4
# 10     -43.4      146.9 2019-04-12           4          96  175.3
# 11     -43.4      146.9 2019-04-16           5          77  268.9
# 12     -43.4      146.9 2019-04-24           3          84  124.2
# 13     -43.4      146.9 2020-03-27           2          32   95.8
# 14     -43.4      146.9 2020-03-28           4          75   91.0
# 15     -43.4      147.0 2018-04-23           3          84  131.0
# 16     -43.4      147.3 2017-04-05           1          89   19.1
# 17     -43.3      146.5 2019-01-29           1          87   31.0
# 18     -43.3      146.5 2019-01-30           4          22  348.2
# 19     -43.3      146.6 2019-01-29           2          72   12.2
#
#     est_fire_area  est_brightness  loc_count
# 0             5.4           306.2          1
# 1             1.2           306.1          1
# 2             1.7           327.8          1
# 3             1.0           297.0         12
# 4             3.2           309.4         12
# 5             2.9           301.8         12
# 6             1.3           315.2         12
# 7             1.3           325.8         12
# 8             1.3           298.4         12
# 9             2.9           311.6         12
# 10            1.0           334.0         12
# 11            1.4           323.7         12
# 12            6.8           300.8         12
# 13            1.3           320.6         12
# 14            4.2           309.4         12
# 15            1.3           315.7          1
# 16            1.1           300.4          1
# 17            1.0           314.9          2
# 18            5.4           309.0          2
# 19            1.0           304.8          1

# %%
## Normalizing

# %%
confidence_norm = preprocessing.normalize([fire_copy['confidence']], norm='max')
frp_norm = preprocessing.normalize([fire_copy['frp']], norm='max')
area_norm = preprocessing.normalize([fire_copy['est_fire_area']], norm='max')
count_norm = preprocessing.normalize([fire_copy['fire_count']], norm='max')

# %%
fire_copy['ranking'] = confidence_norm[0]*0.4 + frp_norm[0]*0.2 + area_norm[0]*0.2 + count_norm[0]*0.2

# %%
fire_copy = fire_copy.sort_values(by=['loc_count'], ascending=False)
fire_copy.head(30)
# Out:
#         latitude  longitude       time  fire_count  confidence   frp  \
# 184355     -20.6      116.8 2017-05-08           1          74  14.1
# 181967     -20.8      115.4 2016-03-04           5          86  54.6
# 181943     -20.8      115.4 2016-02-01           2          66  20.2
# 181944     -20.8      115.4 2016-02-02           5          64  29.5
# 181945     -20.8      115.4 2016-02-03           5          84  34.4
# 181946     -20.8      115.4 2016-02-04           2          88  29.6
# 181947     -20.8      115.4 2016-02-06           1          88  19.5
# 181948     -20.8      115.4 2016-02-07           4          74  15.1
# 181949     -20.8      115.4 2016-02-09           2          66  25.4
# 181950     -20.8      115.4 2016-02-10           3          82  14.3
# 181951     -20.8      115.4 2016-02-11           1          87  17.1
# 181952     -20.8      115.4 2016-02-12           6          76  26.2
# 181953     -20.8      115.4 2016-02-13           1          82  11.2
# 181954     -20.8      115.4 2016-02-14           2          82  14.9
# 181955     -20.8      115.4 2016-02-15           1          91  24.6
# 181956     -20.8      115.4 2016-02-18           1          96  14.6
# 181957     -20.8      115.4 2016-02-20           2          77  19.4
# 181958     -20.8      115.4 2016-02-21           1          80  16.1
# 181959     -20.8      115.4 2016-02-23           1          42   4.0
# 181960     -20.8      115.4 2016-02-25           1          91  12.2
# 181961     -20.8      115.4 2016-02-27           2          85  29.2
# 181962     -20.8      115.4 2016-02-28           3          57  16.4
# 181963     -20.8      115.4 2016-02-29           4          69  32.8
# 181964     -20.8      115.4 2016-03-01           4          82  26.0
# 181965     -20.8      115.4 2016-03-02           4          88  40.0
# 181942     -20.8      115.4 2016-01-31           1          41  15.0
# 181941     -20.8      115.4 2015-12-15           1           0  52.0
# 181940     -20.8      115.4 2015-12-14           5          71  21.1
# 184365     -20.6      116.8 2017-05-27           1          82   9.9
# 184375     -20.6      116.8 2017-08-02           1          62  17.3
#
#         est_fire_area  est_brightness  loc_count   ranking
# 184355            1.1           317.7        211  0.321056
# 181967            2.2           321.1        211  0.399909
# 181943            1.9           303.5        211  0.307549
# 181944            2.1           312.5        211  0.308842
# 181945            1.9           314.3        211  0.384867
# 181946            2.1           313.5        211  0.400084
# 181947            1.1           324.8        211  0.377268
# 181948            1.5           309.7        211  0.334191
# 181949            3.8           303.6        211  0.347336
# 181950            1.5           313.4        211  0.364572
# 181951            1.7           306.6        211  0.385674
# 181952            2.2           311.2        211  0.360383
# 181953            1.3           321.6        211  0.357109
# 181954            1.4           303.0        211  0.360925
# 181955            1.0           326.4        211  0.387384
# 181956            1.2           309.0        211  0.411159
# 181957            2.1           313.9        211  0.355685
# 181958            2.2           303.2        211  0.368051
# 181959            1.2           298.8        211  0.194744
# 181960            1.0           306.4        211  0.386899
# 181961            2.2           314.1        211  0.390152
# 181962            1.8           304.5        211  0.270904
# 181963            3.5           311.6        211  0.356551
# 181964            1.2           310.4        211  0.360368
# 181965            2.4           317.3        211  0.409916
# 181942            2.7           299.7        211  0.222425
# 181941            4.6           321.5        211  0.099458
# 181940            2.1           308.8        211  0.336513
# 184365            1.0           303.0        211  0.350808
# 184375            1.4           307.4        211  0.279432

# %%
fire_copy.to_csv(f"{fileName}_prepared.csv.gz", index=False, compression='gzip')

# %%
fire_copy.to_csv(f"{fileName}_prepared.csv", index=False)
